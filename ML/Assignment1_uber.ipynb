# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('uber.csv')
df
# Out:
#         Unnamed: 0                            key  fare_amount  \
# 0         24238194    2015-05-07 19:52:06.0000003          7.5
# 1         27835199    2009-07-17 20:04:56.0000002          7.7
# 2         44984355   2009-08-24 21:45:00.00000061         12.9
# 3         25894730    2009-06-26 08:22:21.0000001          5.3
# 4         17610152  2014-08-28 17:47:00.000000188         16.0
# ...            ...                            ...          ...
# 134075    55085753   2013-02-02 06:49:00.00000040          7.5
# 134076    29950951    2009-04-29 16:22:43.0000002         45.0
# 134077     1881342   2012-02-17 00:00:00.00000041          5.7
# 134078    38670107    2014-01-11 17:39:40.0000004         11.0
# 134079    15898018    2013-04-20 22:49:00.0000006          9.0
#
#                 pickup_datetime  pickup_longitude  pickup_latitude  \
# 0       2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1       2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2       2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3       2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4       2014-08-28 17:47:00 UTC        -73.925023        40.744085
# ...                         ...               ...              ...
# 134075  2013-02-02 06:49:00 UTC        -73.977332        40.738025
# 134076  2009-04-29 16:22:43 UTC        -73.800131        40.645728
# 134077  2012-02-17 00:00:00 UTC        -73.973197        40.759218
# 134078  2014-01-11 17:39:40 UTC        -73.994131        40.750950
# 134079  2013-04-20 22:49:00 UTC          0.000000         0.000000
#
#         dropoff_longitude  dropoff_latitude  passenger_count
# 0              -73.999512         40.723217              1.0
# 1              -73.994710         40.750325              1.0
# 2              -73.962565         40.772647              1.0
# 3              -73.965316         40.803349              3.0
# 4              -73.973082         40.761247              5.0
# ...                   ...               ...              ...
# 134075         -73.959735         40.762802              1.0
# 134076         -73.978649         40.783169              1.0
# 134077         -73.972288         40.747183              1.0
# 134078         -73.987784         40.732606              2.0
# 134079                NaN               NaN              NaN
#
# [134080 rows x 9 columns]

# %%
df.head()
# Out:
#    Unnamed: 0                            key  fare_amount  \
# 0    24238194    2015-05-07 19:52:06.0000003          7.5
# 1    27835199    2009-07-17 20:04:56.0000002          7.7
# 2    44984355   2009-08-24 21:45:00.00000061         12.9
# 3    25894730    2009-06-26 08:22:21.0000001          5.3
# 4    17610152  2014-08-28 17:47:00.000000188         16.0
#
#            pickup_datetime  pickup_longitude  pickup_latitude  \
# 0  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217              1.0
# 1         -73.994710         40.750325              1.0
# 2         -73.962565         40.772647              1.0
# 3         -73.965316         40.803349              3.0
# 4         -73.973082         40.761247              5.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134080 entries, 0 to 134079
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         134080 non-null  int64
#  1   key                134080 non-null  object
#  2   fare_amount        134080 non-null  float64
#  3   pickup_datetime    134080 non-null  object
#  4   pickup_longitude   134080 non-null  float64
#  5   pickup_latitude    134080 non-null  float64
#  6   dropoff_longitude  134078 non-null  float64
#  7   dropoff_latitude   134078 non-null  float64
#  8   passenger_count    134079 non-null  float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 9.2+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0    fare_amount  pickup_longitude  pickup_latitude  \
# count  1.340800e+05  134080.000000     134080.000000    134080.000000
# mean   2.769425e+07      11.364389        -72.513632        39.937783
# std    1.601203e+07       9.855329         11.500953         8.426162
# min    4.800000e+01     -52.000000      -1340.648410       -74.015515
# 25%    1.379821e+07       6.000000        -73.992060        40.734840
# 50%    2.776430e+07       8.500000        -73.981812        40.752648
# 75%    4.152615e+07      12.500000        -73.967056        40.767128
# max    5.542290e+07     350.000000         57.418457      1644.421482
#
#        dropoff_longitude  dropoff_latitude  passenger_count
# count      134078.000000     134078.000000    134079.000000
# mean          -72.521304         39.912992         1.679965
# std            14.292738          7.039498         1.418083
# min         -3356.666300       -881.985513         0.000000
# 25%           -73.991412         40.733747         1.000000
# 50%           -73.980113         40.752971         1.000000
# 75%           -73.963732         40.767977         2.000000
# max          1153.572603        872.697628       208.000000

# %%
df.drop(['Unnamed: 0','key'], axis = 1, inplace = True)

# %%
df.isnull().sum()
# Out:
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    2
# dropoff_latitude     2
# passenger_count      1
# dtype: int64

# %%
df['dropoff_latitude'].fillna(value = df['dropoff_latitude'].mean(), inplace = True)
df['dropoff_longitude'].fillna(value = df['dropoff_longitude'].mean(), inplace = True)
df['passenger_count'].fillna(value = df['passenger_count'].mean(), inplace = True)

# %%
df.isnull().sum()
# Out:
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    0
# dropoff_latitude     0
# passenger_count      0
# dtype: int64

# %%
df.dtypes
# Out:
# fare_amount          float64
# pickup_datetime       object
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count      float64
# dtype: object

# %%
df = df.drop(['pickup_datetime'], axis = 1)

# %%
df.dtypes
# Out:
# fare_amount          float64
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count      float64
# dtype: object

# %%
df.plot(kind = "box", subplots = True, layout = (7,2), figsize=(15,20))
# Out:
# fare_amount             Axes(0.125,0.786098;0.352273x0.0939024)
# pickup_longitude     Axes(0.547727,0.786098;0.352273x0.0939024)
# pickup_latitude         Axes(0.125,0.673415;0.352273x0.0939024)
# dropoff_longitude    Axes(0.547727,0.673415;0.352273x0.0939024)
# dropoff_latitude        Axes(0.125,0.560732;0.352273x0.0939024)
# passenger_count      Axes(0.547727,0.560732;0.352273x0.0939024)
# dtype: object

# %%
#Using the InterQuartile Range to fill the values
def remove_outlier(df1 , col):
    Q1 = df1[col].quantile(0.25)
    Q3 = df1[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_whisker = Q1-1.5*IQR
    upper_whisker = Q3+1.5*IQR
    df[col] = np.clip(df1[col] , lower_whisker , upper_whisker)
    return df1

def treat_outliers_all(df1 , col_list):
    for c in col_list:
        df1 = remove_outlier(df , c)
    return df1

treat_outliers_all(df, df.iloc[: , 0::])
# Out:
#         fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0              7.50        -73.999817        40.738354         -73.999512
# 1              7.70        -73.994355        40.728225         -73.994710
# 2             12.90        -74.005043        40.740770         -73.962565
# 3              5.30        -73.976124        40.790844         -73.965316
# 4             16.00        -73.929550        40.744085         -73.973082
# ...             ...               ...              ...                ...
# 134075         7.50        -73.977332        40.738025         -73.959735
# 134076        22.25        -73.929550        40.686408         -73.978649
# 134077         5.70        -73.973197        40.759218         -73.972288
# 134078        11.00        -73.994131        40.750950         -73.987784
# 134079         9.00        -73.929550        40.686408         -73.922211
#
#         dropoff_latitude  passenger_count
# 0              40.723217         1.000000
# 1              40.750325         1.000000
# 2              40.772647         1.000000
# 3              40.803349         3.000000
# 4              40.761247         3.500000
# ...                  ...              ...
# 134075         40.762802         1.000000
# 134076         40.783169         1.000000
# 134077         40.747183         1.000000
# 134078         40.732606         2.000000
# 134079         40.682397         1.679965
#
# [134080 rows x 6 columns]

# %%
df.plot(kind = "box", subplots = True, layout = (7,2), figsize=(15,20))
# Out:
# fare_amount             Axes(0.125,0.786098;0.352273x0.0939024)
# pickup_longitude     Axes(0.547727,0.786098;0.352273x0.0939024)
# pickup_latitude         Axes(0.125,0.673415;0.352273x0.0939024)
# dropoff_longitude    Axes(0.547727,0.673415;0.352273x0.0939024)
# dropoff_latitude        Axes(0.125,0.560732;0.352273x0.0939024)
# passenger_count      Axes(0.547727,0.560732;0.352273x0.0939024)
# dtype: object

# %%
sns.heatmap(df.corr(),annot = True) #Correlation Heatmap
# Out:
# <Axes: >

# %%
x = df.drop(['fare_amount'], axis = 1)
y = df['fare_amount']

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.33)

# %%
y_test
# Out:
# 42154     22.25
# 84664      5.30
# 36486      7.70
# 77236     12.50
# 93489      4.50
#           ...
# 91887      6.90
# 56325     10.50
# 45165     10.00
# 117286     5.00
# 118474     7.70
# Name: fare_amount, Length: 44247, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([13.73455761, 10.00010741,  8.75378339, ...,  9.80612647,
#        10.31861225, 10.43005143])

# %%
from sklearn import metrics

# %%
mse = metrics.mean_squared_error(y_test, y_pred)
print("mean squared errot : ", mse)
# Out:
# mean squared errot :  27.113925541028195

# %%
print("Root mean squared error : ",np.sqrt(mse))
# Out:
# Root mean squared error :  5.207103373376429

# %%
r2 = metrics.r2_score(y_test, y_pred)
print("r2 score : ", r2)
# Out:
# r2 score :  0.08697194787817775

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred  = model.predict(x_test)
y_pred
# Out:
# array([22.25  ,  5.976 ,  6.3835, ..., 11.5035,  5.6355,  9.772 ])

# %%
mse = metrics.mean_squared_error(y_test, y_pred)
print("mean squared errot : ", mse)
# Out:
# mean squared errot :  7.207216564306175

# %%
print("Root mean squared error : ",np.sqrt(mse))
# Out:
# Root mean squared error :  2.6846259635759644

# %%
r2 = metrics.r2_score(y_test, y_pred)
print("r2 score : ", r2)
# Out:
# r2 score :  0.7573058577972674
